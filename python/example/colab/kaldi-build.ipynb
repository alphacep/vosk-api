# %%
# !apt-get install -qq g++ automake autoconf libtool gfortran sox subversion
# !git clone -b vosk --single-branch https://github.com/alphacep/kaldi.git
# Out:
# Selecting previously unselected package libapr1:amd64.
# (Reading database ... 156084 files and directories currently installed.)
# Preparing to unpack .../libapr1_1.6.3-2_amd64.deb ...
# Unpacking libapr1:amd64 (1.6.3-2) ...
# Selecting previously unselected package libaprutil1:amd64.
# Preparing to unpack .../libaprutil1_1.6.1-2_amd64.deb ...
# Unpacking libaprutil1:amd64 (1.6.1-2) ...
# Selecting previously unselected package libserf-1-1:amd64.
# Preparing to unpack .../libserf-1-1_1.3.9-6_amd64.deb ...
# Unpacking libserf-1-1:amd64 (1.3.9-6) ...
# Selecting previously unselected package libsvn1:amd64.
# Preparing to unpack .../libsvn1_1.9.7-4ubuntu1.1_amd64.deb ...
# Unpacking libsvn1:amd64 (1.9.7-4ubuntu1.1) ...
# Selecting previously unselected package subversion.
# Preparing to unpack .../subversion_1.9.7-4ubuntu1.1_amd64.deb ...
# Unpacking subversion (1.9.7-4ubuntu1.1) ...
# Setting up libapr1:amd64 (1.6.3-2) ...
# Setting up libaprutil1:amd64 (1.6.1-2) ...
# ...

# %%
# %cd /content/kaldi/tools
# !make -j 8 cub openfst
# !extras/install_openblas.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ...
# sbdsdc.f:464:0: Warning: ‘poles’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# sbdsdc.f:464:0: Warning: ‘ivt’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# sbdsdc.f:464:0: Warning: ‘is’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# sbdsdc.f:464:0: Warning: ‘ic’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# sbdsdc.f:464:0: Warning: ‘givnum’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# sbdsdc.f:464:0: Warning: ‘givcol’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# sbdsdc.f:464:0: Warning: ‘difr’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# sbdsdc.f:464:0: Warning: ‘difl’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC  -c -o sdisna.o sdisna.f
# ...

# %%
# !extras/install_opengrm.sh
# Out:
# ****() Installing OpenGrm
# Could not find OpenGrm tarball ngram-1.3.12.tar.gz
# Trying to download it via wget!
# --2022-08-17 00:17:58--  http://www.opengrm.org/twiki/pub/GRM/NGramDownload/ngram-1.3.12.tar.gz
# Resolving www.opengrm.org (www.opengrm.org)... 206.196.111.47
# Connecting to www.opengrm.org (www.opengrm.org)|206.196.111.47|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.opengrm.org/twiki/pub/GRM/NGramDownload/ngram-1.3.12.tar.gz [following]
# --2022-08-17 00:17:58--  https://www.opengrm.org/twiki/pub/GRM/NGramDownload/ngram-1.3.12.tar.gz
# Connecting to www.opengrm.org (www.opengrm.org)|206.196.111.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13982107 (13M) [application/x-gzip]
# Saving to: ‘ngram-1.3.12.tar.gz’
#
# ngram-1.3.12.tar.gz 100%[===================>]  13.33M  10.3MB/s    in 1.3s
#
# 2022-08-17 00:18:00 (10.3 MB/s) - ‘ngram-1.3.12.tar.gz’ saved [13982107/13982107]
# ...

# %%
# %cd /content/kaldi/src/
# !./configure --shared --mathlib=OPENBLAS
# Out:
# [Errno 2] No such file or directory: '/content/kaldi/src/'
# /content
# /bin/bash: ./configure: No such file or directory

# %%
# !make -j 4
# Out:
# test -d /content/kaldi/src/lib || mkdir /content/kaldi/src/lib
# make depend
# The version of configure script matches kaldi.mk version. Good.
# make[1]: Entering directory '/content/kaldi/src'
# make -C base/ depend
# make -C bin/ depend
# make -C chain/ depend
# make -C chainbin/ depend
# make[2]: Entering directory '/content/kaldi/src/base'
# make[2]: Entering directory '/content/kaldi/src/chainbin'
# make[2]: Entering directory '/content/kaldi/src/chain'
# make[2]: Entering directory '/content/kaldi/src/bin'
# rm -f .depend.mk
# ...

# %%
# !du -ms /content/kaldi
# Out:
# 6611	/content/kaldi

# %%
# !find /content/kaldi -name "*.o" -exec rm {} \;
# !find /content/kaldi -name "*.a" -exec rm {} \;
# !rm -rf /content/kaldi/egs
# !rm -rf /content/kaldi/.git

# %%
# %cd /content/
# !tar czf kaldi.tar.gz kaldi
# Out:
# /content

# %%
# !ls -la
# Out:
# total 1067964
# drwxr-xr-x  1 root root       4096 Aug 17 03:00 .
# drwxr-xr-x  1 root root       4096 Aug 16 22:59 ..
# drwxr-xr-x  4 root root       4096 Aug 15 13:44 .config
# drwxr-xr-x  2 root root       4096 Aug 17 03:00 .ipynb_checkpoints
# drwxr-xr-x 10 root root       4096 Aug 17 03:00 kaldi
# -rw-r--r--  1 root root 1093564144 Aug 17 03:03 kaldi.tar.gz
# drwxr-xr-x  1 root root       4096 Aug 15 13:44 sample_data
